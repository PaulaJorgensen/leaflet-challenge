# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_to_load = "data/data.csv"

data = pd.read_csv(file_to_load)
data.head()
# Out:
#    case_no  number_killed  number_injured            location         state  \
# 0        2              4               0           Workplace      New York
# 1        3              4               1               Other  Pennsylvania
# 2        4              4               1              Retail  Pennsylvania
# 3        5              4              17               Other  Pennsylvania
# 4        6             32              26  College/University      Virginia
#
#   shooter_last_name shooter_first_name  full_date day_of_week  day  ...  \
# 0             White             Joseph  9/23/1970   Wednesday   23  ...
# 1          Belmonte             Victor  7/21/1980      Monday   21  ...
# 2     O'Brien Smith            Timothy  1/28/2018      Sunday   28  ...
# 3         Lambright             Donald   4/5/1969    Saturday    5  ...
# 4               Cho          Seung-Hui  4/16/2007      Monday   16  ...
#
#     race               education  relationship_status  \
# ...

# %%
data.columns
# Out:
# Index(['case_no', 'number_killed', 'number_injured', 'location', 'state',
#        'shooter_last_name', 'shooter_first_name', 'full_date', 'day_of_week',
#        'day', 'month', 'year', 'zip_code', 'latitude', 'longitude', 'city',
#        'region', 'urbansuburbanrural', 'victims_known_or_unknown', 'age',
#        'gender', 'race', 'education', 'relationship_status',
#        'specify_relationship_to_other_shootings',
#        'total_weapons_brought_to_the_scene', 'crime_violence_confact_pct',
#        'trauma_crisis_confact_pct', 'mental_health_confact_pct',
#        'motivation_confact_pct', 'social_contagion_confact_pct'],
#       dtype='object')

# %%
sm_data=data.loc[:,["number_killed", "number_injured", "full_date",  
                   "day", "month", "year", "city", "state", "location", "urbansuburbanrural", "age", "gender", "education",
                   "relationship_status", "crime_violence_confact_pct", "trauma_crisis_confact_pct", 
                   "mental_health_confact_pct", "motivation_confact_pct", "social_contagion_confact_pct"]]
sm_data
# Out:
#      number_killed  number_injured   full_date  day  month  year  \
# 0                4               0   9/23/1970   23      9  1970
# 1                4               1   7/21/1980   21      7  1980
# 2                4               1   1/28/2018   28      1  2018
# 3                4              17    4/5/1969    5      4  1969
# 4               32              26   4/16/2007   16      4  2007
# 5                5               1  12/31/1994   31     12  1994
# 6                8               1   5/17/1984   17      5  1984
# 7                4               0   11/9/1991    9     11  1991
# 8                5               3  10/16/1981   16     10  1981
# 9                7               1    8/7/2011    7      8  2011
# 10               6               2  11/21/2004   21     11  2004
# 11               5               2  11/12/1966   12     11  1966
# 12               6               0  11/14/2015   14     11  2015
# ...

# %%
victims=sm_data["number_killed"].count()
# victims
states=sm_data["state"].value_counts()
# states
genders=sm_data["gender"].value_counts()
genders
# Out:
# Male      168
# Female      3
# Name: gender, dtype: int64

# %%
group_state=sm_data.groupby(['state'])
state_count=group_state.count().head(10)
state_count
state_avg=group_state.mean()
state_avg
state_percent=state_count/state_avg *100
state_percent.head(15)
# Out:
#                             age  city  crime_violence_confact_pct         day  \
# state
# Alabama                4.347826   NaN                         NaN    4.000000
# Alaska                 9.183673   NaN                         NaN   42.857143
# Arizona               13.636364   NaN                         NaN   25.714286
# Arkansas              15.789474   NaN                         NaN   12.328767
# California            75.615213   NaN                         NaN  233.910035
# Colorado              25.000000   NaN                         NaN   41.860465
# Connecticut           10.112360   NaN                         NaN   39.130435
# District of Columbia   2.941176   NaN                         NaN    6.250000
# Florida               33.202358   NaN                         NaN   86.666667
# Georgia                5.194805   NaN                         NaN   10.000000
# Hawaii                      NaN   NaN                         NaN         NaN
# ...

# %%
group_state["number_killed"].sum()
kill_count=group_state["number_killed"].sum()
kill_count.head()
# Out:
# state
# Alabama         4
# Alaska         18
# Arizona        15
# Arkansas       15
# California    179
# Name: number_killed, dtype: int64

# %%
summary = pd.DataFrame({"Number of Shootings":states, "Number of Victims Killed":kill_count})
summary.head()

shooting_summary=summary.sort_values("Number of Victims Killed", ascending=False)
shooting_summary.head()
# Out:
#               Number of Shootings  Number of Victims Killed
# California                     26                       179
# Texas                          18                       154
# Florida                        13                       130
# Nevada                          3                        66
# Pennsylvania                   10                        53

# %%
top_states=state_count>10
top_states

state_chart = states.plot(kind='bar')
state_chart.set_xlabel("Age Bracket")

plt.tight_layout()
# plt.savefig("state_chart.png")
plt.show(10)

# %%
group_gender=sm_data.groupby(['gender'])
gender_count=group_gender.count().head(10)

# %%
group_gender["number_killed"].sum()
kill_gender=group_gender["number_killed"].sum()
kill_gender.head()
# Out:
# gender
# Female      25
# Male      1214
# Name: number_killed, dtype: int64

# %%
g_summary = pd.DataFrame({"Gender Count":genders, "Number of Victims Killed":kill_gender})
g_summary.head()
# Out:
#         Gender Count  Number of Victims Killed
# Female             3                        25
# Male             168                      1214

# %%
gender_group=sm_data.groupby('gender')
count_gender=gender_group['gender'].count()
# count_gender

count_chart = count_gender.plot(kind='bar')
count_chart.set_xlabel("Gender")
count_chart.set_ylabel("Number")

plt.show()
plt.tight_layout()

# %%
bins =[0, 17, 24, 38, 59, 200]

group_labels = ["0-17", "18-24", "25-39", "40-60", "60 and over"]

# %%
sm_data["Age Group"] = pd.cut(sm_data["age"], bins, labels=group_labels)
sm_data.head()
# Out:
#    number_killed  number_injured  full_date  day  month  year  \
# 0              4               0  9/23/1970   23      9  1970
# 1              4               1  7/21/1980   21      7  1980
# 2              4               1  1/28/2018   28      1  2018
# 3              4              17   4/5/1969    5      4  1969
# 4             32              26  4/16/2007   16      4  2007
#
#                 city         state            location urbansuburbanrural  \
# 0             Albany      New York           Workplace              Urban
# 1         Coraopolis  Pennsylvania               Other           Suburban
# 2  Saltlick Township  Pennsylvania              Retail              Rural
# 3         Harrisburg  Pennsylvania               Other              Urban
# 4         Blacksburg      Virginia  College/University              Rural
#
#    age gender               education relationship_status  \
# 0   25   Male  Graduate School/Degree              Single
# ...

# %%
ages=sm_data["age"].sum()
# ages

# %%
age= sm_data.groupby("Age Group")
# print(age["Age Group"].count())
age[["age"]].count()
ages=age[["age"]].count()
ages
# Out:
#              age
# Age Group
# 0-17           7
# 18-24         40
# 25-39         61
# 40-60         57
# 60 and over    6

# %%
labels = ["0-17", "18-24", "25-39", "40-60", "60+"]
sizes= [7, 40, 61, 57, 6]
colors = ["red", "orange", "lightcoral", "lightblue", "grey"]
explode = (0.5,0,0,0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, 
       autopct="%1.1f%%", shadow=True, startangle=95)
plt.title=("Age of Shooters %")
plt.savefig("age_pie.png")
plt.show()

# %%
age_chart = ages.plot(kind='bar')
count_chart.set_xlabel("Age Bracket")

plt.tight_layout()
plt.savefig("age_chart.png")
plt.show()
